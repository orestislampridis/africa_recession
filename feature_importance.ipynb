# %% [markdown]
# <a href="https://colab.research.google.com/github/orestislampridis/advanced_ML_project/blob/master/feature_importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import eli5
from eli5.sklearn import PermutationImportance

# %%
def scale_data(dataframe):
    minmax = MinMaxScaler()
    columns = list(df.columns.values)
    scaled_df = minmax.fit_transform(dataframe)
    scaled_df = pd.DataFrame(scaled_df, columns=columns)
    return scaled_df

# %%
df = pd.read_csv('africa_recession.csv', error_bad_lines=False)
df = scale_data(df)

X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

class_names = ["no recession", "recession"]

X_resampled, y_resampled = SMOTE(random_state=0).fit_resample(X, y)

model = xgboost.XGBClassifier().fit(X_resampled,y_resampled)
perm = PermutationImportance(model).fit(X_resampled, y_resampled)
a = HTML((eli5.show_weights(perm, feature_names=X.columns.tolist())))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-14b6d0b27b6d> in <module>()
# ----> 1 df = pd.read_csv('africa_recession.csv', error_bad_lines=False)
#       2 df = scale_data(df)
#       3
#       4 X = df.iloc[:, 0:-1]
#       5 y = df.iloc[:, -1]
#
# ...
